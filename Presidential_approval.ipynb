# %%
# Import dependency
import pandas as pd

# %%
# Load the csv data file
csv = 'Resources/approval_polllist.csv'

# Read the csv file as a Pandas dataframe
df = pd.read_csv(csv)

# Show the dataframe
df
# Out:
#           president   subgroup  modeldate  startdate    enddate  \
# 0      Donald Trump  All polls  8/31/2020  1/20/2017  1/22/2017
# 1      Donald Trump  All polls  8/31/2020  1/20/2017  1/22/2017
# 2      Donald Trump  All polls  8/31/2020  1/20/2017  1/24/2017
# 3      Donald Trump  All polls  8/31/2020  1/21/2017  1/23/2017
# 4      Donald Trump  All polls  8/31/2020  1/22/2017  1/24/2017
# ...             ...        ...        ...        ...        ...
# 14542  Donald Trump     Voters  8/31/2020  8/27/2020  8/28/2020
# 14543  Donald Trump     Voters  8/31/2020  8/26/2020  8/30/2020
# 14544  Donald Trump     Voters  8/31/2020  8/27/2020  8/29/2020
# 14545  Donald Trump     Voters  8/31/2020  8/28/2020  8/30/2020
# 14546  Donald Trump     Voters  8/31/2020  8/30/2020  8/31/2020
#
#                                        pollster grade  samplesize population  \
# 0                                        Gallup     B      1500.0          a
# 1                               Morning Consult   B/C      1992.0         rv
# 2                                         Ipsos    B-      1632.0          a
# 3                                        Gallup     B      1500.0          a
# 4      Rasmussen Reports/Pulse Opinion Research    C+      1500.0         lv
# ...                                         ...   ...         ...        ...
# 14542                                    YouGov     B       807.0         rv
# 14543  Rasmussen Reports/Pulse Opinion Research    C+      1500.0         lv
# 14544                                    YouGov     B       789.0         rv
# 14545                                    YouGov     B       764.0         rv
# 14546                           Emerson College    A-      1567.0         lv
#
#          weight  ...  disapprove  adjusted_approve  adjusted_disapprove  \
# 0      0.262323  ...        45.0         45.765945            43.590621
# 1      0.680029  ...        37.0         45.285652            37.781866
# 2      0.153481  ...        45.2         43.199569            43.853862
# 3      0.242845  ...        46.0         45.765945            44.590621
# 4      0.200411  ...        43.0         51.601406            44.437696
# ...         ...  ...         ...               ...                  ...
# 14542  0.182970  ...        54.0         42.362936            53.353449
# 14543  0.507394  ...        51.0         42.803609            51.794244
# 14544  0.178889  ...        53.0         45.362936            52.353449
# 14545  0.189977  ...        53.0         44.362936            52.353449
# 14546  2.188095  ...        46.9         47.877327            49.456294
#
#        multiversions  tracking  \
# 0                NaN         T
# 1                NaN       NaN
# 2                NaN         T
# 3                NaN         T
# 4                NaN         T
# ...              ...       ...
# 14542            NaN       NaN
# 14543            NaN         T
# 14544            NaN       NaN
# 14545            NaN       NaN
# 14546            NaN       NaN
#
#                                                      url poll_id question_id  \
# 0      http://www.gallup.com/poll/201617/gallup-daily...   49253       77265
# 1      http://static.politico.com/9b/13/82a3baf542ae9...   49249       77261
# 2                http://polling.reuters.com/#poll/CP3_2/   49426       77599
# 3      http://www.gallup.com/poll/201617/gallup-daily...   49262       77274
# 4      http://www.rasmussenreports.com/public_content...   49266       77278
# ...                                                  ...     ...         ...
# 14542  https://docs.cdn.yougov.com/trcdohan8j/2020082...   68246      127845
# 14543  http://www.rasmussenreports.com/public_content...   68257      127866
# 14544  https://today.yougov.com/_pubapis/v5/us/tracke...   68260      127872
# 14545  https://today.yougov.com/_pubapis/v5/us/tracke...   68272      127889
# 14546  https://emersonpolling.reportablenews.com/pr/a...   68268      127884
#
#        createddate        timestamp
# 0        1/23/2017  8/31/2020 18:23
# 1        1/23/2017  8/31/2020 18:23
# 2         3/1/2017  8/31/2020 18:23
# 3        1/24/2017  8/31/2020 18:23
# 4        1/25/2017  8/31/2020 18:23
# ...            ...              ...
# 14542    8/29/2020  8/31/2020 18:27
# 14543    8/31/2020  8/31/2020 18:27
# 14544    8/31/2020  8/31/2020 18:27
# 14545    8/31/2020  8/31/2020 18:27
# 14546    8/31/2020  8/31/2020 18:27
#
# [14547 rows x 22 columns]

# %%
# Reorder the columns to match the column order of other dataframes to be merged with
presidential_approval = df[['pollster', 'startdate', 'enddate', 'approve', 'disapprove', 'grade', 
                            'samplesize', 'population', 'weight']]

# Rename columns to match the column names of the other polling dataset
presidential_approval = presidential_approval.rename(columns={"pollster":"Poll", "startdate":"Start_Date", "enddate":"End_Date", "approve":"Approve", 
                         "disapprove":"Disapprove", "grade":"Grade", "samplesize":"Sample", 
                         "population":"Population", "weight":"Weight"})

# %%
# Apply uppercase to the 'Population' column to be consistent with the formatting of the other polling dataset
presidential_approval['Population'] = presidential_approval['Population'].str.upper()

# %%
presidential_approval.dtypes
# Out:
# Poll           object
# Start_Date     object
# End_Date       object
# Approve       float64
# Disapprove    float64
# Grade          object
# Sample        float64
# Population     object
# Weight        float64
# dtype: object

# %%
# Alter 'Start Date' & 'End Date' columns to be in datetime format, again for consistent formatting
presidential_approval['Start_Date'] = pd.to_datetime(presidential_approval['Start_Date'].str.strip(), format = '%m/%d/%Y')
presidential_approval['End_Date'] = pd.to_datetime(presidential_approval['End_Date'].str.strip(), format = '%m/%d/%Y')

# %%
# View the cleaned-up dataframe
presidential_approval
# Out:
#                                            Poll Start_Date   End_Date  \
# 0                                        Gallup 2017-01-20 2017-01-22
# 1                               Morning Consult 2017-01-20 2017-01-22
# 2                                         Ipsos 2017-01-20 2017-01-24
# 3                                        Gallup 2017-01-21 2017-01-23
# 4      Rasmussen Reports/Pulse Opinion Research 2017-01-22 2017-01-24
# ...                                         ...        ...        ...
# 14542                                    YouGov 2020-08-27 2020-08-28
# 14543  Rasmussen Reports/Pulse Opinion Research 2020-08-26 2020-08-30
# 14544                                    YouGov 2020-08-27 2020-08-29
# 14545                                    YouGov 2020-08-28 2020-08-30
# 14546                           Emerson College 2020-08-30 2020-08-31
#
#        Approve  Disapprove Grade  Sample Population    Weight
# 0        45.00        45.0     B  1500.0          A  0.262323
# 1        46.00        37.0   B/C  1992.0         RV  0.680029
# 2        42.10        45.2    B-  1632.0          A  0.153481
# 3        45.00        46.0     B  1500.0          A  0.242845
# 4        57.00        43.0    C+  1500.0         LV  0.200411
# ...        ...         ...   ...     ...        ...       ...
# 14542    43.00        54.0     B   807.0         RV  0.182970
# 14543    47.00        51.0    C+  1500.0         LV  0.507394
# 14544    46.00        53.0     B   789.0         RV  0.178889
# 14545    45.00        53.0     B   764.0         RV  0.189977
# 14546    48.47        46.9    A-  1567.0         LV  2.188095
#
# [14547 rows x 9 columns]

# %%
# Save to a new csv file
presidential_approval.to_csv('Output_data/presidential_approval.csv')
